# %% [markdown]
# # 4.7 Lesson Deriving New Variables

# %% [markdown]
# # Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing 'ords_prods_merged' dataframe
# path = r'D:\Rich\Bus Analyst\29-06-2023 Instacart Basket Analysis'
# 'ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))'

# %%
path = r'D:\Rich\Bus Analyst\29-06-2023 Instacart Basket Analysis'

# %%
path
# Out:
# 'D:\\Rich\\Bus Analyst\\29-06-2023 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
# Check consistency
# 'ords_prods_merge.head()'
# 'ords_prods_merge.shape'
# 'ords_prods_merge.describe()'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# 25%         1.000000e+01            5.000000e+00  1.354400e+04
# ...

# %% [markdown]
# # Create a subset with the following code 'df = ords_prods_merge[:1000000]'

# %%
df = ords_prods_merge[:1000000]

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  order_dow  \
# 0        2539329        1    prior             1          2
# 1        2398795        1    prior             2          3
# 2         473747        1    prior             3          3
# 3        2254736        1    prior             4          4
# 4         431534        1    prior             5          4
# ...          ...      ...      ...           ...        ...
# 999995   2836489   164627    prior            14          0
# 999996   1843600   164632    prior             5          1
# 999997    733106   164632    prior             9          2
# 999998   1650124   164632    prior            17          6
# 999999   3378258   164632    prior            22          6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                       8                     NaN         196
# 1                       7                    15.0         196
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %% [markdown]
# # Defining the 'price_label' function and apply it to the subset 'df = ords_prods_merge[:1000000] that was just created.

# %%
# Define a function

def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\rblj\AppData\Local\Temp\ipykernel_22016\93659844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
# Checking on what the most expensive product within the subset is using the 'max()' function

df['prices'].max()
# Out:
# 14.8

# %%
# The maximum value within the 'prices' column is 14.8

# %% [markdown]
# # If-Statements with the loc() function
#
# # 'df.loc[df['prices'] > 15 , 'price_range_loc'] = 'Higher range product'
# # 'df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'
# # df.loc[df['prices'] < = 5, 'price_range-loc'] = 'Low range product'

# %%
df.loc[df['prices'] > 15 , 'price_range_loc'] = 'Higher range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range-loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If-Statement with 'ords_prods_merge' data set using 'loc()'.
#
# # 'ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High range product'
#
# # 'ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid range product'
#
# # 'ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'
#
# # 'ords_prods_merge['price_range_loc'].value_counts(dropna = False)'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10131448
# High-range product      412551
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If-Statements with For-Loops
#
# # Create a new column 'orders_day_of _week'
#
# # In the 'ords_prods_merge' dataframe look at which day most orders take place.  Printing the frequency of the 'orders_day_of_week' column.

# %%
# Create a new column 'orders_day_of _the_week' and copy values from 'order_dow' to the new column
# 'ords_prods_merge['orders_day_of_the_week'] = ords_prods_merge['order_dow']'

ords_prods_merge['orders_day_of_the_week'] = ords_prods_merge['order_dow']

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %% [markdown]
# # Create the code for 'Busiest day', 'Least busy', and 'Regularly busy' with the new column 'orders_day_of_week'
#
# # result =[]
#
# # for value in ords_prods_merge["orders_day_of_week"]:
# #    if value == 0:
# #       result.append("Busiest day")
#
# #    elif value == 4:
# #        result.append("Least busy")
#
# #    else:
# #         result.append("Regularly busy")

# %%
result = []

for value in ords_prods_merge["orders_day_of_the_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Slowest days',
#  'Regular busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular busy',
# ...

# %%
# Create a new column within 'ords_prods_merge' dataframe and set it equal to 'result'
# 'ords_prods_merge['Busiest_day'] = result'

ords_prods_merge['Busiest_day'] = result

# %%
# Checking the frequency and compare with previous frequency of 'orders_day_of_the_week'

# %%
ords_prods_merge['Busiest_day'].value_counts(dropna = False)
# Out:
# Regular busy    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest_day, dtype: int64

# %%
# The frequencies for 'Busiest day' and 'Least busy' are the same

# %% [markdown]
# # 4.7 Task

# %% [markdown]
# # Step 1 was completed during the lesson portion, see above.

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# # Step 2: Client changed their minds and want to change 'Busiest day' to 'Busiest days' (plural) the two busiest days of the week. Also, they want to know the two 'slowest days'. Create the new column using a suitable method.

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
# Needed to rename 'Busiest_day' column,to'Busiest_days' column
ords_prods_merge.rename(columns = {'Busiest_day' : 'Busiest_days'}, inplace = True)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
# Create the code for 'Busiest days' and 'Slowest days' in the new column 'Busiest_days'

# %%
ords_prods_merge['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_the_week"]:
    if value == 0 or value == 1:
        result.append("Busiest days")
    elif value == 3 or value == 4:
        result.append("Slowest days")
    else:
        result.append("Regular busy")

# %%
ords_prods_merge['Busiest_days'] = result

# %%
result
# Out:
# ['Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Slowest days',
#  'Regular busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular busy',
# ...

# %%
ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regular busy    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest_days, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# # Step 3 Check the values of the new column for accuracy and note any observations in a markdown format.

# %%
# Check the values of 'Busiest_days' column for accuracy.

ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regular busy    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest_days, dtype: int64

# %% [markdown]
# # Obersavations: There are more orders on 'Regular busy' days, which are Monday, Thursday, and Friday. Next highest is 'Busiest days' which are Saturday and Sunday and then the 'Slowest days' are Tuesday and Wednesday.

# %% [markdown]
# # Step 4: The senior technical office wants the busiest hours of the day, rather than by the hour. Label periods of time 'Most orders', 'Average orders', and 'Fewest orders'.  Create a new column called 'busiest_period_of_day'.

# %%
# Create a new column 'busiest_period_of_day'
# 'ords_prods_merge['busiest_period_of_day'] = ords_prods_merge['order_hour_of_day']''

# %%
ords_prods_merge['busiest_period_of_day'] = ords_prods_merge['order_hour_of_day']

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Create a code for 'Most orders', 'Fewest orders' and 'Average orders'

# %% [markdown]
# # I will make three groups of 8 hours per busiest_result
#
# # busiest_result = []
#
# # for hour in ords_prods_merge["order_hour_of_day"]:
# #            if hour in [10, 11, 14, 15, 13, 12, 16, 9]:
# #                   busiest_result.append("Most orders")
# #            elif hour in [23, 6, 0, 1, 5, 2, 4, 3]:
# #                    busiest_result.append("Fewest orders")
# #             else:
# #                     busiest_result.append("Average orders")

# %%
# Create a 'for loop' code for 'Most orders', 'Fewest orders' and 'Average orders' 

busiest_result = []

for hour in ords_prods_merge["order_hour_of_day"]:
    if hour in [10, 11, 14, 15, 13, 12, 16, 9]:
        busiest_result.append("Most orders")
    elif hour in [23, 6, 0, 1, 5, 2, 4, 3]:
        busiest_result.append("Fewest orders")
    else:
        busiest_result.append("Average orders")

# %%
busiest_result
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day'] = busiest_result

# %% [markdown]
# # Step 5 Print frequecy of the new column

# %%
# Print the frequency of 'busiest_period_of_day' column

ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # Step 6 Ensure notebook is clean and structured and the codes are well commented

# %% [markdown]
# # Step 7 Export the dataframe as a pickle file and store it correctly in 'Prepared Data' folder.
# # ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
